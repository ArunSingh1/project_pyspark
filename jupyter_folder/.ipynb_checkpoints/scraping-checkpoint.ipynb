# %%
from twython import Twython



#credentials['CONSUMER_KEY'] 
APP_KEY = "n4XUxW5VFjygbfn11b0qlQtPN"
#credentials['CONSUMER_SECRET'] 
APP_SECRET = "9K8NhQZU57DlttBk7OpfALtmFzI8LDSCZJKShYwvVUzXaNuxnR"
#credentials['ACCESS_TOKEN'] 
OAUTH_TOKEN = "1394047431281623042-QN1mFN7N88IKIt5OOCpuaGTfLBAIUP"
#credentials['ACCESS_SECRET'] 
OAUTH_TOKEN_SECRET= "NL0pZvd3Gy7BVZbIAL11qcmCxTtJ2XX2Yafnpro73CGud"


twitter = Twython(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)


# https://api.twitter.com/1.1/search/tweets.json?q=%23test&include_entities=true
# Create our query
query = {'q': 'FriendsReunion',
         'result_type': 'mixed',
         'count': 20,
         'lang': 'en',
#          'geocode': "-74.781157,-73.398720,50km", 
#          #"37.781157,-122.398720,50km" 
         'include_entities' : 'True'         
        }


import pandas as pd

# Search tweets
# dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
# for status in twitter.search(**query)['statuses']:
#     dict_['user'].append(status['user']['screen_name'])
#     dict_['date'].append(status['created_at'])
#     dict_['text'].append(status['text'])
#     dict_['favorite_count'].append(status['favorite_count'])

# Search tweets
dict_ = {'tweet_id': [], 'user': [], 'user_id' : [],  'date': [], 'text': [], 'hashtags' : [], 'profilepic': [], 'retweet_count' : [], 
         'location': [],'favorite_count': [], 'is_Verfied' : [], 'followers_count':[],  'joined_in' : [], 'geo': [], 'place' : [], 'source': []}
for status in twitter.search(**query)['statuses']:
    dict_['tweet_id'].append(status['id'])
    dict_['user'].append(status['user']['screen_name'])
    dict_['user_id'].append(status['user']['id'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['hashtags'].append(status['entities']['hashtags'])
    dict_['profilepic'].append(status['user']['profile_image_url'])
    dict_['location'].append(status['user']['location'])
    dict_['retweet_count'].append(status['retweet_count'])
    dict_['favorite_count'].append(status['favorite_count'])
    dict_['is_Verfied'].append(status['user']['verified'])
    dict_['followers_count'].append(status['user']['followers_count'])
    dict_['joined_in'].append(status['user']['created_at'])
    dict_['geo'].append(status['geo'])
    dict_['place'].append(status['place'])
    dict_['source'].append(status['source'])

    


# # Structure data in a pandas DataFrame for easier manipulation
# df = pd.DataFrame(dict_)
# df.sort_values(by='favorite_count', inplace=True, ascending=False)
# df.head(15)
# # df.shape


# df['profilepic'][1]

# %%
from twython import TwythonStreamer
class MyStreamer(TwythonStreamer):
    def on_success(self, data):
        if 'text' in data:
            print(data['text'])

    def on_error(self, status_code, data):
        print(status_code)
        
MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
stream.statuses.filter(track='twitter')
# Out:
# RT @OgrendikceVariz: Çoğunlukla evde vakit geçirdiğiniz şu dönemlerde, spor salonuna gitmeden yapabileceğiniz bazı hareketler. https://t.co…
# RT @mementojai: サマータイム甘雨ちゃん　#原神 https://t.co/bHZDbUuPMl
# RT @soompi: WATCH: #MAMAMOO Talks About The Meaning Of Their Upcoming Comeback In Spoiler Film
# https://t.co/ptoBLd35NP https://t.co/eEzIl6k…
# RT @saroooshhh: they’re not just numbers. https://t.co/OgfOv68Dku
# @PawsworthWrites The name's Gachato. I'm a *relatively* lucky demigod, and I love playing games with friends, espec… https://t.co/ZieRRmmMlK
# RT @martibatres: https://t.co/k9e4fvW888
# RT @omgsovalid: ⌗ ¡Ymir de Shingeki no Kyojin es lesbiana! https://t.co/TUcagX9LIc
# RT @MyBookieBet: “The ole dick twist” https://t.co/sAFgmwieb7
# 我慢できずにブライトマヤノウマ箱のありったけの女神像をピースに変えて☆4開花出来た😭　#ウマ娘 https://t.co/mhCVtS49eP
# RT @IR_Lab: How does light placement affect the look of your portrait subject? Zach Sutton over at @Lensrentals wrote an excellent guide to…
# RT @thecodemiko: The Queen @Valkyrae  of @100Thieves is coming on SUNDAY at 2pm pst! It's finally happening!! I'm so excited! Thank you for…
# RT @ajplusespanol: ¿Ya viste la campaña #PoderPrieto en redes?
#
# Hablamos con la actriz mexicana Maya Zapata (@LaMZapata) sobre las razones…
# RT @BrasilGenshin: Sorteio de uma Benção da Lua Nova!
# ⠀
# Regras do sorteio:
# — Nos seguir;
# — Dar rt no post.
# ⠀
# Fácil, não? E para concorrer b…
# RT @BTS_twt: 맞아요
# 사실은 염색 했습니다
# #JIMIN https://t.co/S2ldTcpYp0
# RT @2DACIA339: #28May  Los combatientes de la .@zodilarainvicta estan comprometidos en la defensa de la Nación. 🇻🇪   #FANB #GNB
# #MuralesBic…
# RT @Alexxussh: I’ll be releasing a physical and digital copy of my investing journal 📔 💻.
#
# Sign up to be notified first when they’re availa…
# @yuppilovr @suj6ong @yangmichicoemo ustedes conocen a san martin voy a poner el bts https://t.co/TxJee9CPDU
# RT @DeLambda: La tristesse du réseau
# ⚜TOP BOTTOM 🍑💦⚜
# 🔂🔂🔂
# @plushyoongs
# @Christian_Ch28
# @ChrissOrlin38
# #RT
# #Christian_Ch28
# #ChrissOrlin38
# #gaytwins… https://t.co/sZPTBUPsnz
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-10-7d2f76bd484a> in <module>
#       9
#      10 stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# ---> 11 stream.statuses.filter(track='twitter')
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/types.py in filter(self, **params)
#      45         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      46               % self.streamer.api_version
# ---> 47         self.streamer._request(url, 'POST', params=params)
#      48
#      49     def sample(self, **params):
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/api.py in _request(self, url, method, params)
#     137             response = _send(retry_counter)
#     138
# --> 139             for line in response.iter_lines(self.chunk_size):
#     140                 if not self.connected:
#     141                     break
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     806
#     807             if lines and lines[-1] and chunk and lines[-1][-1] == chunk[-1]:
# --> 808                 pending = lines.pop()
#     809             else:
#     810                 pending = None
#
# KeyboardInterrupt:

# %%
# # Search tweets
# dict_ = {'user': [], 'date': [], 'text': [], 'retweet_count' = [], 'favorite_count': []}
# for status in twitter.search(**query)['statuses']:
#     dict_['user'].append(status['user']['screen_name'])
#     dict_['date'].append(status['created_at'])
#     dict_['text'].append(status['text'])
#     dict_['text'].append(status['retweet_count'])
#     dict_['favorite_count'].append(status['favorite_count'])


dict_ = {'tweet_id': [], 'user': [], 'user_id' : [],  'date': [], 'text': [], 'hashtags' : [], 'profilepic': [], 'retweet_count' : [], 
         'location': [],'favorite_count': [], 'is_Verfied' : [], 'followers_count':[],  'joined_in' : [], 'geo': [], 'place' : [], 'source': []}
for status in twitter.search(**query)['statuses']:
    dict_['tweet_id'].append(status['id'])
    dict_['user'].append(status['user']['screen_name'])
    dict_['user_id'].append(status['user']['id'])
    dict_['date'].append(status['created_at'])
    dict_['text'].append(status['text'])
    dict_['hashtags'].append(status['entities']['hashtags'])
    dict_['profilepic'].append(status['user']['profile_image_url'])
    dict_['location'].append(status['user']['location'])
    dict_['retweet_count'].append(status['retweet_count'])
    dict_['favorite_count'].append(status['favorite_count'])
    dict_['is_Verfied'].append(status['user']['verified'])
    dict_['followers_count'].append(status['user']['followers_count'])
    dict_['joined_in'].append(status['user']['created_at'])
    dict_['geo'].append(status['geo'])
    dict_['place'].append(status['place'])
    dict_['source'].append(status['source'])

# %%
from twython import TwythonStreamer
import csv

# Filter out unwanted data
def process_tweet(tweet):
    
    dict_ = {'tweet_id': [], 'user': [], 'user_id' : [],  'date': [], 'text': [], 'hashtags' : [], 'profilepic': [], 'retweet_count' : [], 
         'location': [],'favorite_count': [], 'is_Verfied' : [], 'followers_count':[],  'joined_in' : [], 'geo': [], 'source': []}
    
    dict_['tweet_id']=(tweet['id'])
    dict_['user']=(tweet['user']['screen_name'])
    dict_['user_id']=(tweet['user']['id'])
    dict_['date']=(tweet['created_at'])
    dict_['text']=(tweet['text'])
    dict_['hashtags']=[hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    dict_['profilepic']=(tweet['user']['profile_image_url'])
    dict_['location']=(tweet['user']['location'])
    dict_['retweet_count']=(tweet['retweet_count'])
    dict_['favorite_count']=(tweet['favorite_count'])
    dict_['is_Verfied']=(tweet['user']['verified'])
    dict_['followers_count']=(tweet['user']['followers_count'])
    dict_['joined_in']=(tweet['user']['created_at'])
    dict_['geo']=(tweet['geo'])
    dict_['source']=(tweet['source'])

    return dict_
    
    
# Create a class that inherits TwythonStreamer
class MyStreamer(TwythonStreamer):     

    # Received data
    def on_success(self, data):

        # Only collect tweets in English
        if data['lang'] == 'en':
            tweet_data = process_tweet(data)
            print(tweet_data)
            #df1 = pd.DataFrame(tweet_data)
            self.save_to_csv(tweet_data)

    # Problem with the API
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()
        
    # Save each tweet to csv file
    def save_to_csv(self, tweet):
        with open(r'saved_tweets77.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(list(tweet.values()))

# %%
df1
# Out:
# ---------------------------------------------------------------------
# NameError                           Traceback (most recent call last)
# <ipython-input-118-6a861a8b3f1a> in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
# # Instantiate from our streaming class
# stream = MyStreamer(creds['CONSUMER_KEY'], creds['CONSUMER_SECRET'], 
#                     creds['ACCESS_TOKEN'], creds['ACCESS_SECRET'])
# # Start the stream
# stream.statuses.filter(track='python')


stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
stream.statuses.filter(track='python')
# Out:
# {'tweet_id': 1398419028767563779, 'user': 'BtpTechSearch', 'user_id': 1633428576, 'date': 'Fri May 28 23:20:52 +0000 2021', 'text': 'RT @StrangeFactoid: The Python programming language was not named after the snake, but was actually named after "Monty Python\'s Flying Circ…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/378800000215671410/3ae4aa058cb2a197a001b77331c3d354_normal.jpeg', 'retweet_count': 0, 'location': 'Coral Springs, FL ', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2253, 'joined_in': 'Tue Jul 30 17:45:37 +0000 2013', 'geo': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'}
# {'tweet_id': 1398419046626910211, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:20:56 +0000 2021', 'text': 'RT @TrendingNews_7: Deployment of #MachineLearning Models in Production with #Python Code https://t.co/nZ5YXNpa8R\n\n#BigData #Analytics #Dat…', 'hashtags': ['MachineLearning', 'Python', 'BigData', 'Analytics'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419049508376580, 'user': 'RobOttoBots', 'user_id': 1381744487358078979, 'date': 'Fri May 28 23:20:57 +0000 2021', 'text': "RT @Sheraj99: The Hacker's Way Lang, #Jupyter Notebook: #Mathematics for #DataScience. #BigData #Analytics #AI #MachineLearning #IoT #IIoT…", 'hashtags': ['Jupyter', 'Mathematics', 'DataScience', 'BigData', 'Analytics', 'AI', 'MachineLearning', 'IoT', 'IIoT'], 'profilepic': 'http://pbs.twimg.com/profile_images/1381744739876175878/g88W9wp-_normal.jpg', 'retweet_count': 0, 'location': 'The Internets', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 338, 'joined_in': 'Mon Apr 12 23:02:48 +0000 2021', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">Rob Otto Bot Twitter</a>'}
# {'tweet_id': 1398419052754833408, 'user': 'Emilyonaire__', 'user_id': 2288923564, 'date': 'Fri May 28 23:20:58 +0000 2021', 'text': "RT @humble: Python is a world-renowned programming language used to make tasks more efficient! Once you start looking you'll see that there…", 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1262972745958260737/tPwzppOA_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 46, 'joined_in': 'Fri Jan 17 23:57:37 +0000 2014', 'geo': None, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'}
# {'tweet_id': 1398419085382193155, 'user': 'richardkimphd', 'user_id': 140618811, 'date': 'Fri May 28 23:21:05 +0000 2021', 'text': 'RT @TrendingNews_7: Deployment of #MachineLearning Models in Production with #Python Code https://t.co/nZ5YXNpa8R\n\n#BigData #Analytics #Dat…', 'hashtags': ['MachineLearning', 'Python', 'BigData', 'Analytics'], 'profilepic': 'http://pbs.twimg.com/profile_images/1342402165189439488/d9vYyh3z_normal.jpg', 'retweet_count': 0, 'location': 'Ulsan, South Korea 🇰🇷', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2788, 'joined_in': 'Thu May 06 00:20:48 +0000 2010', 'geo': None, 'source': '<a href="http://bknc.kr" rel="nofollow">shem0304</a>'}
# {'tweet_id': 1398419093016006659, 'user': 'BotRaj1', 'user_id': 1260015280048222208, 'date': 'Fri May 28 23:21:07 +0000 2021', 'text': 'RT @byLilyV: #FEATURED #COURSES\nComplete #Python #Developer in 2021: Zero to Mastery\nHow to become a #Python3 Developer and get hired\nBuild…', 'hashtags': ['FEATURED', 'COURSES', 'Python', 'Developer', 'Python3'], 'profilepic': 'http://pbs.twimg.com/profile_images/1298179046149255170/2pOFz0EL_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 372, 'joined_in': 'Tue May 12 01:15:47 +0000 2020', 'geo': None, 'source': '<a href="https://twitter.com/BotRaj1" rel="nofollow">PM Softwares</a>'}
# {'tweet_id': 1398419094265806848, 'user': 'pay_examhelp', 'user_id': 1176453755786715136, 'date': 'Fri May 28 23:21:08 +0000 2021', 'text': 'Pay academic experts to help you in;\n#Essay\n#Summer class\n#Exam\n#Project\n#Book review\n#Tests\n#econometrics… https://t.co/OLxnRXx3im', 'hashtags': ['Essay', 'Summer', 'Exam', 'Project', 'Book', 'Tests', 'econometrics'], 'profilepic': 'http://pbs.twimg.com/profile_images/1392262729080180738/PL8IDXzu_normal.jpg', 'retweet_count': 0, 'location': 'California, USA', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 274, 'joined_in': 'Tue Sep 24 11:10:36 +0000 2019', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419095867981824, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:08 +0000 2021', 'text': 'RT @IainLJBrown: Dogtown Media Featured as a 2021 Artificial Intelligence Tech Development Leader by Clutch Research - WFMZ Allentown\n\nRead…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419098237902855, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:09 +0000 2021', 'text': 'RT @IainLJBrown: Michelob Ultra spoofs artificial intelligence to spotlight real ingredients in hard seltzer - Marketing Dive\n\nRead more he…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419100259524608, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:09 +0000 2021', 'text': 'RT @IainLJBrown: Acoustic Quality Control with the Help of Artificial Intelligence - Innovation Origins\n\nRead more here: https://t.co/yVhZa…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419102281129987, 'user': 'essay_maestro', 'user_id': 1250241709822423041, 'date': 'Fri May 28 23:21:10 +0000 2021', 'text': 'We offer best academic services,  avoid last minute rush\n#Paper pay \n#Case study\n#python\n#Onlineclass take… https://t.co/U83yXwNmnr', 'hashtags': ['Paper', 'Case', 'python', 'Onlineclass'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331755901519355904/dtt3gHeb_normal.jpg', 'retweet_count': 0, 'location': 'New York, NY', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 407, 'joined_in': 'Wed Apr 15 01:57:19 +0000 2020', 'geo': None, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'}
# {'tweet_id': 1398419104579661824, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:10 +0000 2021', 'text': 'RT @IainLJBrown: The Impact of Artificial Intelligence on the IC – The Cipher Brief - The Cipher Brief\n\nRead more here: https://t.co/3gM3Us…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419106437767170, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:11 +0000 2021', 'text': 'RT @IainLJBrown: Artificial intelligence can help spot traces of natural selection - Imperial College London\n\nRead more here: https://t.co/…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419107876413441, 'user': 'aProgrammerBot', 'user_id': 1330350611796209666, 'date': 'Fri May 28 23:21:11 +0000 2021', 'text': 'RT @TrendingNews_7: Deployment of #MachineLearning Models in Production with #Python Code https://t.co/nZ5YXNpa8R\n\n#BigData #Analytics #Dat…', 'hashtags': ['MachineLearning', 'Python', 'BigData', 'Analytics'], 'profilepic': 'http://pbs.twimg.com/profile_images/1364039854682558467/Z98f0cUL_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count':
 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419141674086404, 'user': 'AzureTweetbot', 'user_id': 1347471985287323648, 'date': 'Fri May 28 23:21:19 +0000 2021', 'text': 'RT @africanaffairs: Now playing on African Affairs Radio: fall by davido! \nTune in now: https://t.co/4PJNyYARst\nhttps://t.co/vPWVVJEfq7\n#cl…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1347472210630422528/Tv1nIwFl_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 113, 'joined_in': 'Fri Jan 08 09:15:41 +0000 2021', 'geo': None, 'source': '<a href="http://azure.microsoft.com/en-us/services/app-service/logic/" rel="nofollow">Microsoft Azure Logic Apps</a>'}
# {'tweet_id': 1398419145520263168, 'user': 'Bob_gamedev', 'user_id': 1327015921538510850, 'date': 'Fri May 28 23:21:20 +0000 2021', 'text': 'RT @IainLJBrown: Artificial Intelligence Enhances Preventive Care, Telehealth #ArtificialIntelligence #AI #DataScience #100DaysOfCode #Pyth…', 'hashtags': ['ArtificialIntelligence', 'AI', 'DataScience', '100DaysOfCode'], 'profilepic': 'http://pbs.twimg.com/profile_images/1327016888413675525/ZYpEOt18_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 635, 'joined_in': 'Thu Nov 12 22:30:42 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">BobtweetBot</a>'}
# {'tweet_id': 1398419151912280064, 'user': 'vishey68', 'user_id': 128926659, 'date': 'Fri May 28 23:21:21 +0000 2021', 'text': 'RT @MSFTReactor: Every coding language and framework is essential in the tool belt of the learning developer 🧰\n\nFrom JavaScript and .NET to…', 'hashtags': [], 'profilepic': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 7, 'joined_in': 'Fri Apr 02 16:41:52 +0000 2010', 'geo': None, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>'}
# {'tweet_id': 1398419163534798848, 'user': 'mcmullarkey', 'user_id': 122614083, 'date': 'Fri May 28 23:21:24 +0000 2021', 'text': 'RT @kierisi: are you streaming data science-related content on Twitch? drop your channel + a brief description so we can start sharing your…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1168641751365705728/cTkllTAb_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2559, 'joined_in': 'Sat Mar 13 08:52:18 +0000 2010', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419178445578246, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:28 +0000 2021', 'text': 'RT @IainLJBrown: Artificial intelligence: a new generation of drug discovery companies - https://t.co/cXVmA5k7Ap\n\nRead more here: https://t…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419180408422409, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:28 +0000 2021', 'text': 'RT @cursortek: CursorTek is #selling #bulk #data of 3k plus #categories like:\n\n#Landscaping #Lawyers #Laundry #DayCare #ChildCare #Building…', 'hashtags': ['selling', 'bulk', 'data', 'categories', 'Landscaping', 'Lawyers', 'Laundry', 'DayCare', 'ChildCare', 'Building'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419193545043975, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:31 +0000 2021', 'text': 'RT @IainLJBrown: Travel Is Coming Back, and Artificial Intelligence May Be Planning Your Next Flight - TIME\n\nRead more here: https://t.co/Q…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419195788943363, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:32 +0000 2021', 'text': 'RT @IainLJBrown: Argonne researchers using artificial intelligence to shape the future of science - Newswise\n\nRead more here: https://t.co/…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419198011969543, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:32 +0000 2021', 'text': 'RT @Wajdialkayal1: LOOK #FOR \n#Analytics #BigData #Rstats #AI #Reactjs #Python #DataScience #Python #MachineLearning #IoT  #flutter #javasc…', 'hashtags': ['FOR', 'Analytics', 'BigData', 'Rstats', 'AI', 'Reactjs', 'Python', 'DataScience', 'Python', 'MachineLearning', 'IoT', 'flutter'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419201463828481, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:33 +0000 2021', 'text': 'RT @IainLJBrown: Travel Is Coming Back, and Artificial Intelligence May Be Planning Your Next Flight - TIME\n\nRead more here: https://t.co/F…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419204248899593, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:34 +0000 2021', 'text': 'RT @IainLJBrown: European Union is Ready to Put a Leash on Artificial Intelligence - Analytics Insight\n\nRead more here: https://t.co/ndiUxN…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419206060843009, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:34 +0000 2021', 'text': 'RT @IainLJBrown: Google Develops Health App Using Artificial Intelligence - CBS Baltimore\n\nRead more here: https://t.co/HURbHEgzpC\n\n#Artifi…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419208640163845, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:35 +0000 2021', 'text': 'RT @IainLJBrown: Five best practice for driving value from artificial intelligence - https://t.co/xY3pC70vcR\n\nRead more here: https://t.co/…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419212880723969, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:36 +0000 2021', 'text': 'RT @IainLJBrown: Neteera CEO on using artificial intelligence to change healthcare - CNBC\n\nRead more here: https://t.co/ZHJksTF5FZ\n\n#Artifi…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419217360330753, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:37 +0000 2021', 'text': 'RT @IainLJBrown: Tesla aspires to become a robotics firm in Artificial Intelligence - Entrepreneur\n\nRead more here: https://t.co/XlM4fyFWv7…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419221776846852, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:38 +0000 2021', 'text': 'RT @IainLJBrown: SensoRy AI Seeks to Protect the Environment Using Artificial Intelligence - GlobeNewswire\n\nRead more here: https://t.co/KX…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419222762377223, 'user': '__phpJobs__', 'user_id': 1028146022373937152, 'date': 'Fri May 28 23:21:38 +0000 2021', 'text': 'ALTA IT Services is hiring: Cloud Solutions Engineer (AWS/ Docker) 100% Remote [Bethesda, MD]… https://t.co/Os8bbgiHHJ', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1028149320518791169/vnS2Qf7I_normal.jpg', 'retweet_count': 0, 'location': 'Remote', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 358, 'joined_in': 'Sat Aug 11 05:08:08 +0000 2018', 'geo': None, 'source': '<a href="https://www.phpjobs.app" rel="nofollow">phpJobs</a>'}
# {'tweet_id': 1398419227577626627, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:39 +0000 2021', 'text': 'RT @IainLJBrown: Using Artificial Intelligence in Administrative Agencies - The Regulatory Review\n\nRead more here: https://t.co/MfJXxDRi5M…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419236733792265, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:42 +0000 2021', 'text': "RT @IainLJBrown: Artificial Intelligence: The Commission's Regulation Proposal And AI Strategy In Luxembourg - Technology - Luxembourg - Mo…", 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419240768712706, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:43 +0000 2021', 'text': 'RT @IainLJBrown: Machine learning platform identifies activated neurons in real-time #ArtificialIntelligence #AI #DataScience #100DaysOfCod…', 'hashtags': ['ArtificialIntelligence', 'AI', 'DataScience'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419244535123969, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:43 +0000 2021', 'text': "RT @IainLJBrown: Here's a great toolkit for Artificial Intelligence (AI) governance within your organisation - Lexology\n\nRead more here: ht…", 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419247253147649, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:44 +0000 2021', 'text': 'RT @WajdiAlkayal: LOOK #FOR \n#Analytics #BigData #Rstats #AI #Reactjs #Python #DataScience #Python #MachineLearning #IoT #ML #javascript #T…', 'hashtags': ['FOR', 'Analytics', 'BigData', 'Rstats', 'AI', 'Reactjs', 'Python', 'DataScience', 'Python', 'MachineLearning', 'IoT', 'ML', 'javascript'], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419250474229762, 'user': 'bexxmodd', 'user_id': 3532655353, 'date': 'Fri May 28 23:21:45 +0000 2021', 'text': 'RT @IainLJBrown: Using Artificial Intelligence in Administrative Agencies - The Regulatory Review\n\nRead more here: https://t.co/MfJXxDRi5M…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1334906847883644935/qmGBCd6b_normal.jpg', 'retweet_count': 0, 'location': 'Maryland, USA', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 8544, 'joined_in': 'Sat Sep 12 01:17:13 +0000 2015', 'geo': None, 'source': '<a href="https://github.com/bexxmodd" rel="nofollow">BexxPersonalBot</a>'}
# {'tweet_id': 1398419300805918723, 'user': 'GradesQuality', 'user_id': 1376260368952098827, 'date': 'Fri May 28 23:21:57 +0000 2021', 'text': 'We offer best academic services,  avoid last minute rush\n#Paper pay \n#Case study\n#python\n#Onlineclass take… https://t.co/kPyCWrEnvI', 'hashtags': ['Paper', 'Case', 'python', 'Onlineclass'], 'profilepic': 'http://pbs.twimg.com/profile_images/1376260710787915776/qmZfoEkv_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 673, 'joined_in': 'Sun Mar 28 19:50:37 +0000 2021', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419300814409742, 'user': 'godfrey_G_', 'user_id': 935446829730291717, 'date': 'Fri May 28 23:21:57 +0000 2021', 'text': "RT @pyconindia: 🚨 CFP for talks and workshops closes tomorrow. 🚨\n⏳ If you're still writing ✍️ your proposals, don't forget to submit it bef…", 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1331728812300767233/vplJ5zhZ_normal.jpg', 'retweet_count': 0, 'location': 'Johannesburg, South Africa', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2030, 'joined_in': 'Tue Nov 28 09:54:38 +0000 2017', 'geo': None, 'source': '<a href="https://mybot.twitter.com" rel="nofollow">AiSpaceBot</a>'}
# {'tweet_id': 1398419325036515335, 'user': 'e_nterdiscipl', 'user_id': 975452621522853890, 'date': 'Fri May 28 23:22:03 +0000 2021', 'text': "RT @Sheraj99: The Hacker's Way Lang, #Jupyter Notebook: #Mathematics for #DataScience. #BigData #Analytics #AI #MachineLearning #IoT #IIoT…", 'hashtags': ['Jupyter', 'Mathematics', 'DataScience', 'BigData', 'Analytics', 'AI', 'MachineLearning', 'IoT', 'IIoT'], 'profilepic': 'http://pbs.twimg.com/profile_images/975455769285013516/v9woXI7E_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2973, 'joined_in': 'Sun Mar 18 19:23:22 +0000 2018', 'geo': None, 'source': '<a href="http://interdiscipl.org" rel="nofollow">inter discipl</a>'}
# {'tweet_id': 1398419365440200704, 'user': 'help_class4', 'user_id': 1392223780597080068, 'date': 'Fri May 28 23:22:12 +0000 2021', 'text': 'Pay academic experts to help you in;\n#Essay\n#Summer class\n#Exam\n#Project\n#Book review\n#Tests\n#econometrics… https://t.co/glK2AkhASz', 'hashtags': ['Essay', 'Summer', 'Exam', 'Project', 'Book', 'Tests', 'econometrics'], 'profilepic': 'http://pbs.twimg.com/profile_images/1392231546707451909/i161Wi90_normal.jpg', 'retweet_count': 0, 'location': 'California, USA', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 5, 'joined_in': 'Tue May 11 21:03:43 +0000 2021', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419376165031936, 'user': 'i_que1', 'user_id': 1157508668285431808, 'date': 'Fri May 28 23:22:15 +0000 2021', 'text': 'RT @LXRYAPPVREL_: #Week9 Python Backpack 🐍 \n\n#WeeklyDrops\n#LXRY\nhttps://t.co/4cytI6HDvY https://t.co/Jw7t12WWSt', 'hashtags': ['Week9', 'WeeklyDrops', 'LXRY'], 'profilepic': 'http://pbs.twimg.com/profile_images/1395474685815672835/rxTUxl-2_normal.jpg', 'retweet_count': 0, 'location': 'Turn on notifications.', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 80620, 'joined_in': 'Sat Aug 03 04:29:06 +0000 2019', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419376815046663, 'user': 'CoderNotesBot', 'user_id': 842956176958476289, 'date': 'Fri May 28 23:22:15 +0000 2021', 'text': 'RT @essay_maestro: We offer best academic services,  avoid last minute rush\n#Paper pay \n#Case study\n#python\n#Onlineclass take\n#Essaypay\n#10…', 'hashtags': ['Paper', 'Case', 'python', 'Onlineclass', 'Essaypay'], 'profilepic': 'http://pbs.twimg.com/profile_images/849166849950568448/Zb0nWTNN_normal.jpg', 'retweet_count': 0, 'location': 'codeanywhere.com', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 8760, 'joined_in': 'Sat Mar 18 04:29:48 +0000 2017', 'geo': None, 'source': '<a href="https://100daysofcode.com" rel="nofollow">30days30sites</a>'}
# {'tweet_id': 1398419379583438851, 'user': 'ULBeowulf', 'user_id': 895816297862373376, 'date': 'Fri May 28 23:22:16 +0000 2021', 'text': 'Ok let me do this python programming exercise so I can finish it ahead of time.\n*Runs into first problem in the fir… https://t.co/vGfrq4EjC0', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1355661835870072836/IhmXWffv_normal.jpg', 'retweet_count': 0, 'location': 'Brazilian Wetlands', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 1705, 'joined_in': 'Fri Aug 11 01:17:03 +0000 2017', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419394989002754, 'user': 'BotRaj1', 'user_id': 1260015280048222208, 'date': 'Fri May 28 23:22:19 +0000 2021', 'text': 'RT @IainLJBrown: Using Artificial Intelligence in Administrative Agencies - The Regulatory Review\n\nRead more here: https://t.co/MfJXxDRi5M…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1298179046149255170/2pOFz0EL_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 372, 'joined_in': 'Tue May 12 01:15:47 +0000 2020', 'geo': None, 'source': '<a href="https://twitter.com/BotRaj1" rel="nofollow">PM Softwares</a>'}
# {'tweet_id': 1398419425607438339, 'user': 'DFremontGameDev', 'user_id': 873278312499617794, 'date': 'Fri May 28 23:22:27 +0000 2021', 'text': 'Using Python in Blender, exporting object to 2D sprites.\nSave me a lot of time!\n\nhttps://t.co/Nd1GXQS4U3… https://t.co/lC5E2ts0Sg', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1123622304259485697/FS7qfMoJ_normal.png', 'retweet_count': 0, 'location': 'Paris, France', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2359, 'joined_in': 'Fri Jun 09 20:39:09 +0000 2017', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">DFremontGameDev</a>'}
# {'tweet_id': 1398419447765946369, 'user': 'rasbt', 'user_id': 865622395, 'date': 'Fri May 28 23:22:32 +0000 2021', 'text': 'RT @kjbird15: I just found this great tutorial on deepnote from Dr. Raschka.  This is a great example of bringing together all different le…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1287228084853374976/urIZjGUK_normal.jpg', 'retweet_count': 0, 'location': 'Madison, Wisconsin', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 53780, 'joined_in': 'Sun Oct 07 02:06:16 +0000 2012', 'geo': None, 'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>'}
# {'tweet_id': 1398419457480007681, 'user': 'JayChance5', 'user_id': 747917675301572608, 'date': 'Fri May 28 23:22:34 +0000 2021', 'text': 'RT @automeme: See how composite AI benefits retailers, doctors and bankers #ArtificialIntelligence #AI #DataScience #100DaysOfCode #Python…', 'hashtags': ['ArtificialIntelligence', 'AI', 'DataScience', '100DaysOfCode', 'Python'], 'profilepic': 'http://pbs.twimg.com/profile_images/887135954867277824/QxNV4uXW_normal.jpg', 'retweet_count': 0, 'location': 'Off Shore', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 581, 'joined_in': 'Tue Jun 28 22:20:44 +0000 2016', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419463029022724, 'user': 'help_class4', 'user_id': 1392223780597080068, 'date': 'Fri May 28 23:22:36 +0000 2021', 'text': 'Hire us to handle your technical papers \n#Paper\n#python\n#homeworkdue \n#chemistry\n#Onlineclass\n#Essaypay… https://t.co/oHdyx2Z60h', 'hashtags': ['Paper', 'python', 'homeworkdue', 'chemistry', 'Onlineclass', 'Essaypay'], 'profilepic': 'http://pbs.twimg.com/profile_images/1392231546707451909/i161Wi90_normal.jpg', 'retweet_count': 0, 'location': 'California, USA', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 5, 'joined_in': 'Tue May 11 21:03:43 +0000 2021', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419473464545287, 'user': 'gunnermattson', 'user_id': 318861574, 'date': 'Fri May 28 23:22:38 +0000 2021', 'text': '@douggpound\n\ngreat poundcast, as usual. but python got to this one before you! classic!\n\nhttps://t.co/r97rPUl8Fg', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1028495567234711552/Clli4dvD_normal.jpg', 'retweet_count': 0, 'location': 'minneapolis', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 197, 'joined_in': 'Fri Jun 17 05:06:13 +0000 2011', 'geo': None, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>'}
# {'tweet_id': 1398419476098469888, 'user': 'bot_tensorflow', 'user_id': 1319903481486950400, 'date': 'Fri May 28 23:22:39 +0000 2021', 'text': 'RT @byLilyV: #FEATURED #COURSES\n\nMachine Learning, Data Science and Deep Learning with Python\n\nComplete hands-on #machine #learning tutoria…', 'hashtags': ['FEATURED', 'COURSES', 'machine', 'learning'], 'profilepic': 'http://pbs.twimg.com/profile_images/1355063491481096195/U1goIMG__normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 91, 'joined_in': 'Sat Oct 24 07:28:32 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">TensorFlow RT Bot</a>'}
# {'tweet_id': 1398419501805412354, 'user': 'bot_tensorflow', 'user_id': 1319903481486950400, 'date': 'Fri May 28 23:22:45 +0000 2021', 'text': 'RT @Sheraj99: Neural Networks Backpropagation Made Easy. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #Python #RStats #…', 'hashtags': ['BigData', 'Analytics', 'DataScience', 'AI', 'MachineLearning', 'IoT', 'IIoT', 'Python', 'RStats'], 'profilepic': 'http://pbs.twimg.com/profile_images/1355063491481096195/U1goIMG__normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 91, 'joined_in': 'Sat Oct 24 07:28:32 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">TensorFlow RT Bot</a>'}
# {'tweet_id': 1398419519123726337, 'user': 'bot_tensorflow', 'user_id': 1319903481486950400, 'date': 'Fri May 28 23:22:49 +0000 2021', 'text': 'RT @Sheraj99: Best Deep Learning Books to Read in 2021. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python #RStats #TensorFlow #J…', 'hashtags': ['BigData', 'Analytics', 'DataScience', 'IoT', 'IIoT', 'PyTorch', 'Python', 'RStats', 'TensorFlow'], 'profilepic': 'http://pbs.twimg.com/profile_images/1355063491481096195/U1goIMG__normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 91, 'joined_in': 'Sat Oct 24 07:28:32 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">TensorFlow RT Bot</a>'}
# {'tweet_id': 1398419532318973955, 'user': 'bot_tensorflow', 'user_id': 1319903481486950400, 'date': 'Fri May 28 23:22:52 +0000 2021', 'text': 'RT @Sheraj99: #TensorFlow 1.x Deep Learning Cookbook. #BigData #Analytics #DataScience #AI #MachineLearning #IoT #IIoT #PyTorch #Python #RS…', 'hashtags': ['TensorFlow', 'BigData', 'Analytics', 'DataScience', 'AI', 'MachineLearning', 'IoT', 'IIoT', 'PyTorch', 'Python'], 'profilepic': 'http://pbs.twimg.com/profile_images/1355063491481096195/U1goIMG__normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 91, 'joined_in': 'Sat Oct 24 07:28:32 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">TensorFlow RT Bot</a>'}
# {'tweet_id': 1398419541278007299, 'user': 'aProgrammerBot', 'user_id': 1330350611796209666, 'date': 'Fri May 28 23:22:54 +0000 2021', 'text': 'RT @Sheraj99: Best Deep Learning Books to Read in 2021. #BigData #Analytics #DataScience #IoT #IIoT #PyTorch #Python #RStats #TensorFlow #J…', 'hashtags': ['BigData', 'Analytics', 'DataScience', 'IoT', 'IIoT', 'PyTorch', 'Python', 'RStats', 'TensorFlow'], 'profilepic': 'http://pbs.twimg.com/profile_images/1364039854682558467/Z98f0cUL_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 819, 'joined_in': 'Sun Nov 22 03:22:36 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">Rosetta App</a>'}
# {'tweet_id': 1398419546000838657, 'user': 'BotRaj1', 'user_id': 1260015280048222208, 'date': 'Fri May 28 23:22:55 +0000 2021', 'text': 'RT @essay_maestro: We offer best academic services,  avoid last minute rush\n#Paper pay \n#Case study\n#python\n#Onlineclass take\n#Essaypay\n#10…', 'hashtags': ['Paper', 'Case', 'python', 'Onlineclass', 'Essaypay'], 'profilepic': 'http://pbs.twimg.com/profile_images/1298179046149255170/2pOFz0EL_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 372, 'joined_in': 'Tue May 12 01:15:47 +0000 2020', 'geo': None, 'source': '<a href="https://twitter.com/BotRaj1" rel="nofollow">PM Softwares</a>'}
# {'tweet_id': 1398419555366707205, 'user': 'realrubberduck1', 'user_id': 1243990473934622720, 'date': 'Fri May 28 23:22:58 +0000 2021', 'text': 'RT @WajdiAlkayal: LOOK #FOR \n#Analytics #BigData #Rstats #AI #Reactjs #Python #DataScience #Python #MachineLearning #IoT #ML #javascript #T…', 'hashtags': ['FOR', 'Analytics', 'BigData', 'Rstats', 'AI', 'Reactjs', 'Python', 'DataScience', 'Python', 'MachineLearning', 'IoT', 'ML', 'javascript'], 'profilepic': 'http://pbs.twimg.com/profile_images/1243999933541294080/7bYJWnHA_normal.png', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 641, 'joined_in': 'Sat Mar 28 19:57:31 +0000 2020', 'geo': None, 'source': '<a href="http://azure.microsoft.com/en-us/services/app-service/logic/" rel="nofollow">Microsoft Azure Logic Apps</a>'}
# {'tweet_id': 1398419558575267840, 'user': 'Bob_gamedev', 'user_id': 1327015921538510850, 'date': 'Fri May 28 23:22:58 +0000 2021', 'text': 'RT @DFremontGameDev: Using Python in Blender, exporting object to 2D sprites.\nSave me a lot of time!\n\nhttps://t.co/Nd1GXQS4U3\n\n#videogame #…', 'hashtags': ['videogame'], 'profilepic': 'http://pbs.twimg.com/profile_images/1327016888413675525/ZYpEOt18_normal.jpg', 'retweet_count': 0, 'location': None, 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 635, 'joined_in': 'Thu Nov 12 22:30:42 +0000 2020', 'geo': None, 'source': '<a href="https://help.twitter.com/en/using-twitter/how-to-tweet#source-labels" rel="nofollow">BobtweetBot</a>'}
# {'tweet_id': 1398419568905818115, 'user': 'Adetomilola__', 'user_id': 1356252746140286976, 'date': 'Fri May 28 23:23:01 +0000 2021', 'text': 'RT @emiko_dest: She swallowed that dick like a python😱😱 No wonder they survive choking, Please vomit the dick😪🤲 https://t.co/8tqYwE9mfC', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1385575188562055172/VvQXPuV8_normal.jpg', 'retweet_count': 0, 'location': 'Canada plix', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 3680, 'joined_in': 'Mon Feb 01 14:47:23 +0000 2021', 'geo': None, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>'}
# {'tweet_id': 1398419589055270915, 'user': 'TujyeKunywa', 'user_id': 4820930547, 'date': 'Fri May 28 23:23:06 +0000 2021', 'text': 'RT @pythonpro: Looking for a business partner (based in Rwanda)with knowledge in Python, Javascript &amp; Django. This is for an e-commerce pla…', 'hashtags': [], 'profilepic': 'http://pbs.twimg.com/profile_images/1178201475824140288/WewzXvhe_normal.jpg', 'retweet_count': 0, 'location': 'United States', 'favorite_count': 0, 'is_Verfied': False, 'followers_count': 2382, 'joined_in': 'Sun Jan 17 12:59:02 +0000 2016', 'geo': None, 'source': '<a href="http://www.twitter.com" rel="nofollow">Tujye kunywa</a>'}
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-117-ffdcfbd2be91> in <module>
#       7
#       8 stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# ----> 9 stream.statuses.filter(track='python')
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/types.py in filter(self, **params)
#      45         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      46               % self.streamer.api_version
# ---> 47         self.streamer._request(url, 'POST', params=params)
#      48
#      49     def sample(self, **params):
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/api.py in _request(self, url, method, params)
#     137             response = _send(retry_counter)
#     138
# --> 139             for line in response.iter_lines(self.chunk_size):
#     140                 if not self.connected:
#     141                     break
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795         pending = None
#     796
# --> 797         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     798
#     799             if pending is not None:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
from twython import TwythonStreamer
import csv

# Filter out unwanted data
def process_tweet(tweet):
    d = {}
    d['hashtags'] = [hashtag['text'] for hashtag in tweet['entities']['hashtags']]
    d['text'] = tweet['text']
    d['user'] = tweet['user']['screen_name']
    d['user_loc'] = tweet['user']['location']
    return d
    
    
# Create a class that inherits TwythonStreamer
class MyStreamer(TwythonStreamer):     

    # Received data
    def on_success(self, data):

        # Only collect tweets in English
        if data['lang'] == 'en':
            tweet_data = process_tweet(data)
            print(tweet_data)
            self.save_to_csv(tweet_data)
            

    # Problem with the API
    def on_error(self, status_code, data):
        print(status_code, data)
        self.disconnect()
        
    # Save each tweet to csv file
    def save_to_csv(self, tweet):
        with open(r'saved_tweets.csv', 'a') as file:
            writer = csv.writer(file)
            writer.writerow(list(tweet.values()))

# %%
stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
stream.statuses.filter(track='python')
# Out:
# {'hashtags': [], 'text': 'RT @IainLJBrown: CHS Begins Development of Artificial Intelligence Software Products for Medical Diagnostic Imaging Industry - Yahoo Financ…', 'user': 'SuzanneC0leman', 'user_loc': 'South East, England'}
# {'hashtags': ['python'], 'text': 'We offer best and affordable services DM \nWrite essay\nOnline classes\npay someone write\n#python\nPhysics\nPay essay\nes… https://t.co/npcZOSp6wI', 'user': 'GradesQuality', 'user_loc': None}
# {'hashtags': ['php', 'phpjobs', 'js', 'node', 'python', 'ruby'], 'text': 'Brown &amp; Brown Inc. is hiring: Cloud Engineer [Daytona Beach, FL] https://t.co/jIkvGicy7o #php #phpjobs #js #node #python #ruby', 'user': '__phpJobs__', 'user_loc': 'Remote'}
# {'hashtags': [], 'text': '@supertylerc Nice! Another thing to add to my list of reasons I love Python.', 'user': 'jackandhishat', 'user_loc': 'Vancouver, British Columbia'}
# {'hashtags': ['machinelearning', 'ad'], 'text': 'RT @machinelearnflx: Data Science, Deep Learning and Machine Learning with Python https://t.co/PzQ4RRmumF  #machinelearning #ad', 'user': 'BlkHwk0ps', 'user_loc': 'Cancún, Quintana Roo, México'}
# ---------------------------------------------------------------------
# KeyboardInterrupt                   Traceback (most recent call last)
# <ipython-input-106-71622422d490> in <module>
#       1 stream = MyStreamer(APP_KEY, APP_SECRET, OAUTH_TOKEN, OAUTH_TOKEN_SECRET)
# ----> 2 stream.statuses.filter(track='python')
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/types.py in filter(self, **params)
#      45         url = 'https://stream.twitter.com/%s/statuses/filter.json' \
#      46               % self.streamer.api_version
# ---> 47         self.streamer._request(url, 'POST', params=params)
#      48
#      49     def sample(self, **params):
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/twython-3.8.2-py3.8.egg/twython/streaming/api.py in _request(self, url, method, params)
#     137             response = _send(retry_counter)
#     138
# --> 139             for line in response.iter_lines(self.chunk_size):
#     140                 if not self.connected:
#     141                     break
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/requests/models.py in iter_lines(self, chunk_size, decode_unicode, delimiter)
#     795         pending = None
#     796
# --> 797         for chunk in self.iter_content(chunk_size=chunk_size, decode_unicode=decode_unicode):
#     798
#     799             if pending is not None:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/requests/models.py in generate()
#     751             if hasattr(self.raw, 'stream'):
#     752                 try:
# --> 753                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     754                         yield chunk
#     755                 except ProtocolError as e:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     762
#     763             while True:
# --> 764                 self._update_chunk_length()
#     765                 if self.chunk_left == 0:
#     766                     break
#
# ~/Documents/projectpyspark/pyspark_venv/lib/python3.8/site-packages/urllib3/response.py in _update_chunk_length(self)
#     692         if self.chunk_left is not None:
#     693             return
# --> 694         line = self._fp.fp.readline()
#     695         line = line.split(b";", 1)[0]
#     696         try:
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# /usr/lib/python3.8/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.8/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# KeyboardInterrupt:
